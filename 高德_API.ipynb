# %% [markdown]
# # 地理编码

# %%
import requests

# %%
key_map='e74e30eea477decea257a35187b91d58'
def geo(address:str) ->dict:
    """获取地理编码"""
    url='https://restapi.amap.com/v3/geocode/geo?parameters'
    params={
        'key':key_map,
        'address':address,
        'output':'json',
    }
    response=requests.get(url,params=params)
    data=response.json()
    return data

# %%
geo('广东省广州市从化区中山大学南方学院')
# Out:
# {'status': '1',
#  'info': 'OK',
#  'infocode': '10000',
#  'count': '1',
#  'geocodes': [{'formatted_address': '广东省广州市从化区中山大学南方学院',
#    'country': '中国',
#    'province': '广东省',
#    'citycode': '020',
#    'city': '广州市',
#    'district': '从化区',
#    'township': [],
#    'neighborhood': {'name': [], 'type': []},
#    'building': {'name': [], 'type': []},
#    'adcode': '440117',
#    'street': [],
#    'number': [],
#    'location': '113.679287,23.632575',
#    'level': '兴趣点'}]}

# %% [markdown]
# ## 路径规划

# %%
key_map='e74e30eea477decea257a35187b91d58'
def walking(origin,destination):
    """步行路径规划"""
    url='https://restapi.amap.com/v3/direction/walking?parameters'
    params={
        'key':key_map,
        'origin':origin,
        'destination':destination,
    }
    response=requests.get(url,params=params)
    data=response.json()
    return data

# %%
geo('广东省广州市从化区龙岗')
# Out:
# {'status': '1',
#  'info': 'OK',
#  'infocode': '10000',
#  'count': '1',
#  'geocodes': [{'formatted_address': '广东省广州市从化区龙岗',
#    'country': '中国',
#    'province': '广东省',
#    'citycode': '020',
#    'city': '广州市',
#    'district': '从化区',
#    'township': [],
#    'neighborhood': {'name': [], 'type': []},
#    'building': {'name': [], 'type': []},
#    'adcode': '440117',
#    'street': [],
#    'number': [],
#    'location': '113.668051,23.600869',
#    'level': '热点商圈'}]}

# %%
walking('113.679287,23.632575','113.668051,23.600869')
# Out:
# {'status': '1',
#  'info': 'ok',
#  'infocode': '10000',
#  'count': '1',
#  'route': {'origin': '113.679287,23.632575',
#   'destination': '113.668051,23.600869',
#   'paths': [{'distance': '4667',
#     'duration': '3734',
#     'steps': [{'instruction': '向南步行161米右转',
#       'orientation': '南',
#       'road': [],
#       'distance': '161',
#       'duration': '129',
#       'polyline': '113.679592,23.632088;113.679609,23.631003;113.679609,23.631003;113.679609,23.630877;113.67964,23.630638',
#       'action': '右转',
#       'assistant_action': [],
#       'walk_type': '0'},
#      {'instruction': '向西步行99米左转',
#       'orientation': '西',
#       'road': [],
#       'distance': '99',
#       'duration': '79',
#       'polyline': '113.67964,23.630634;113.679362,23.630521;113.679201,23.630473;113.679201,23.630473;113.678711,23.630365',
#       'action': '左转',
#       'assistant_action': [],
#       'walk_type': '0'},
#      {'instruction': '向南步行237米左转',
#       'orientation': '南',
#       'road': [],
#       'distance': '237',
#       'duration': '190',
#       'polyline': '113.678711,23.63036;113.678711,23.62934;113.678711,23.62934;113.678707,23.629132;113.678668,23.629058;113.678576,23.628989;113.678424,23.628902;113.678368,23.628841;113.678333,23.628776;113.678303,23.62865;113.678277,23.628372',
#       'action': '左转',
#       'assistant_action': [],
#       'walk_type': '0'},
#      {'instruction': '向南步行498米向右前方行走',
#       'orientation': '南',
#       'road': [],
#       'distance': '498',
#       'duration': '398',
#       'polyline': '113.678273,23.628368;113.678572,23.628338;113.678685,23.628307;113.678685,23.628307;113.678845,23.628234;113.679045,23.628073;113.679158,23.627964;113.679158,23.627964;113.679214,23.627869;113.679236,23.627778;113.67928,23.627526;113.679288,23.627322;113.679288,23.627322;113.679253,23.626853;113.679184,23.626623;113.679141,23.626497;113.679002,23.626259;113.678941,23.626176;113.678711,23.625977;113.67862,23.625864;113.678529,23.62572;113.678438,23.625191;113.678429,23.625056;113.678451,23.624939;113.678572,23.624657',
#       'action': '向右前方行走',
#       'assistant_action': [],
#       'walk_type': '0'},
#      {'instruction': '向西南步行715米左转',
#       'orientation': '西南',
#       'road': [],
#       'distance': '715',
#       'duration': '572',
#       'polyline': '113.678572,23.624653;113.678559,23.62451;113.678416,23.624323;113.678416,23.624323;113.677582,23.623793;113.676532,23.623346;113.676363,23.623255;113.676272,23.623151;113.676111,23.622834;113.676042,23.622739;113.67579,23.622483;113.675499,23.622279;113.675417,23.622174;113.675386,23.622088;113.675378,23.621836;113.675378,23.621836;113.675391,23.62161;113.675434,23.621476;113.675543,23.621359;113.675764,23.621181;113.675846,23.621089;113.675903,23.620994;113.675907,23.620855;113.675877,23.620725;113.675747,23.620547;113.675304,23.620052',
#       'action': '左转',
#       'assistant_action': [],
#       'walk_type': '0'},
#      {'instruction': '向东南步行406米向右前方行走',
#       'orientation': '东南',
#       'road': [],
#       'distance': '406',
#       'duration': '325',
#       'polyline': '113.675299,23.620048;113.675642,23.619991;113.675825,23.619922;113.676901,23.619193;113.677261,23.618785;113.678069,23.61783;113.678069,23.61783;113.678181,23.617656',
#       'action': '向右前方行走',
#       'assistant_action': [],
#       'walk_type': '0'},
#      {'instruction': '沿乌土街向南步行1380米右转',
#       'orientation': '南',
#       'road': '乌土街',
#       'distance': '1380',
#       'duration': '1104',
#       'polyline': '113.678181,23.617652;113.678095,23.617205;113.678051,23.617075;113.677973,23.616923;113.677743,23.616558;113.677609,23.616289;113.677391,23.615816;113.677339,23.615668;113.67714,23.614826;113.677049,23.614323;113.676927,23.613359;113.676845,23.612786;113.676602,23.611489;113.676445,23.610603;113.676445,23.610603;113.676415,23.610438;113.676411,23.610265;113.676411,23.610265;113.676489,23.609848;113.676502,23.609622;113.676493,23.609236;113.676415,23.608746;113.676415,23.608485;113.67648,23.60819;113.67661,23.607734;113.676819,23.606736;113.676862,23.606541;113.676914,23.606415;113.677014,23.606254;113.677535,23.605673',
#       'action': '右转',
#       'assistant_action': [],
#       'walk_type': '0'},
#      {'instruction': '沿乌土街向西南步行165米直行',
#       'orientation': '西南',
#       'road': '乌土街',
#       'distance': '165',
#       'duration': '132',
#       'polyline': '113.677535,23.605668;113.676988,23.605373;113.676402,23.605;113.676163,23.604887',
#       'action': '直行',
#       'assistant_action': [],
#       'walk_type': '0'},
#      {'instruction': '沿934县道向西步行118米直行',
#       'orientation': '西',
#       'road': '934县道',
#       'distance': '118',
#       'duration': '94',
#       'polyline': '113.676159,23.604883;113.675929,23.604831;113.675599,23.604783;113.675599,23.604783;113.675013,23.60474',
#       'action': '直行',
#       'assistant_action': [],
#       'walk_type': '0'},
#      {'instruction': '沿桃园东路向西南步行673米向右前方行走',
#       'orientation': '西南',
#       'road': '桃园东路',
#       'distance': '673',
#       'duration': '538',
#       'polyline': '113.675009,23.604735;113.674236,23.604683;113.673893,23.604618;113.673464,23.604492;113.673464,23.604492;113.672457,23.60421;113.672457,23.60421;113.67168,23.604006;113.671541,23.603958;113.671411,23.603854;113.671068,23.603472;113.670807,23.603264;113.670807,23.603264;113.670525,23.603073;113.6702,23.602904;113.6702,23.602904;113.670022,23.602795;113.670022,23.602795;113.669909,23.602682;113.669818,23.602517;113.669787,23.602413;113.669718,23.601901',
#       'action': '向右前方行走',
#       'assistant_action': [],
#       'walk_type': '0'},
#      {'instruction': '沿桃园东路向西南步行215米到达目的地',
#       'orientation': '西南',
#       'road': '桃园东路',
#       'distance': '215',
#       'duration': '172',
#       'polyline': '113.669714,23.601897;113.66964,23.601771;113.66964,23.601771;113.669488,23.601558;113.669488,23.601558;113.668789,23.600859;113.668663,23.600768;113.668663,23.600768;113.668442,23.600647;113.668234,23.600547',
#       'action': [],
#       'assistant_action': '到达目的地',
#       'walk_type': '0'}]}]}}

# %%
help(geo)
# Out:
# Help on function geo in module __main__:
#
# geo(address:str) -> dict
#     获取地理编码

# %% [markdown]
# ## 行政区域查询

# %%
key_map='e74e30eea477decea257a35187b91d58'
def district(keywords):
    """行政区域查询"""
    url='https://restapi.amap.com/v3/config/district?parameters'
    params={
        'key':key_map,
        'keywords':keywords,
        'subdistrict':2,
        'extensions':'base',
        'output':'json',
    }
    response=requests.get(url,params=params)
    data=response.json()
    return data

# %%
district('深圳')
# Out:
# {'status': '1',
#  'info': 'OK',
#  'infocode': '10000',
#  'count': '1',
#  'suggestion': {'keywords': [], 'cities': []},
#  'districts': [{'citycode': '0755',
#    'adcode': '440300',
#    'name': '深圳市',
#    'center': '114.085947,22.547',
#    'level': 'city',
#    'districts': [{'citycode': '0755',
#      'adcode': '440306',
#      'name': '宝安区',
#      'center': '113.828671,22.754741',
#      'level': 'district',
#      'districts': [{'citycode': '0755',
#        'adcode': '440306',
#        'name': '松岗街道',
#        'center': '113.864,22.837',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440306',
#        'name': '沙井街道',
#        'center': '113.827,22.7008',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440306',
#        'name': '深圳市宝安国际机场',
#        'center': '113.832,22.6468',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440306',
#        'name': '西乡街道',
#        'center': '113.824,22.5449',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440306',
#        'name': '石岩街道',
#        'center': '113.941,22.7068',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440306',
#        'name': '福永街道',
#        'center': '113.856,22.6742',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440306',
#        'name': '新安街道',
#        'center': '113.91,22.5987',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440306',
#        'name': '福海街道',
#        'center': '113.827,22.6995',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440306',
#        'name': '航城街道',
#        'center': '113.853,22.6071',
#        'level': 'street',
#        'districts': []}]},
#     {'citycode': '0755',
#      'adcode': '440305',
#      'name': '南山区',
#      'center': '113.92943,22.531221',
#      'level': 'district',
#      'districts': [{'citycode': '0755',
#        'adcode': '440305',
#        'name': '招商街道',
#        'center': '113.921,22.4885',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440305',
#        'name': '沙河街道',
#        'center': '113.957,22.5347',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440305',
#        'name': '西丽街道',
#        'center': '113.945,22.6508',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440305',
#        'name': '桃源街道',
#        'center': '114.019,22.5792',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440305',
#        'name': '粤海街道',
#        'center': '113.956,22.5327',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440305',
#        'name': '南头街道',
#        'center': '113.909,22.5517',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440305',
#        'name': '蛇口街道',
#        'center': '113.852,22.4966',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440305',
#        'name': '南山街道',
#        'center': '113.927,22.5135',
#        'level': 'street',
#        'districts': []}]},
#     {'citycode': '0755',
#      'adcode': '440304',
#      'name': '福田区',
#      'center': '114.05096,22.541009',
#      'level': 'district',
#      'districts': [{'citycode': '0755',
#        'adcode': '440304',
#        'name': '沙头街道',
#        'center': '113.995,22.5325',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440304',
#        'name': '莲花街道',
#        'center': '114.054,22.5624',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440304',
#        'name': '园岭街道',
#        'center': '114.105,22.5607',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440304',
#        'name': '福保街道',
#        'center': '114.065,22.5177',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440304',
#        'name': '华强北街道',
#        'center': '114.089,22.5489',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440304',
#        'name': '南园街道',
#        'center': '114.097,22.5408',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440304',
#        'name': '梅林街道',
#        'center': '114.007,22.5768',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440304',
#        'name': '香蜜湖街道',
#        'center': '113.998,22.5485',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440304',
#        'name': '福田保税区',
#        'center': '114.064,22.5099',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440304',
#        'name': '华富街道',
#        'center': '114.086,22.57',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440304',
#        'name': '福田街道',
#        'center': '114.083,22.5302',
#        'level': 'street',
#        'districts': []}]},
#     {'citycode': '0755',
#      'adcode': '440308',
#      'name': '盐田区',
#      'center': '114.235366,22.555069',
#      'level': 'district',
#      'districts': [{'citycode': '0755',
#        'adcode': '440308',
#        'name': '海山街道',
#        'center': '114.25,22.5611',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440308',
#        'name': '市保税区',
#        'center': '114.242,22.5594',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440308',
#        'name': '梅沙街道',
#        'center': '114.281,22.6424',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440308',
#        'name': '盐田街道',
#        'center': '114.252,22.5626',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440308',
#        'name': '沙头角街道',
#        'center': '114.205,22.5706',
#        'level': 'street',
#        'districts': []}]},
#     {'citycode': '0755',
#      'adcode': '440303',
#      'name': '罗湖区',
#      'center': '114.123885,22.555341',
#      'level': 'district',
#      'districts': [{'citycode': '0755',
#        'adcode': '440303',
#        'name': '笋岗街道',
#        'center': '114.104,22.5621',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440303',
#        'name': '东门街道',
#        'center': '114.116,22.5428',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440303',
#        'name': '黄贝街道',
#        'center': '114.157,22.5662',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440303',
#        'name': '桂园街道',
#        'center': '114.109,22.556',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440303',
#        'name': '南湖街道',
#        'center': '114.113,22.5389',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440303',
#        'name': '清水河街道',
#        'center': '114.082,22.5699',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440303',
#        'name': '东晓街道',
#        'center': '114.123,22.589',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440303',
#        'name': '东湖街道',
#        'center': '114.204,22.5699',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440303',
#        'name': '翠竹街道',
#        'center': '114.128,22.574',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440303',
#        'name': '莲塘街道',
#        'center': '114.205,22.565',
#        'level': 'street',
#        'districts': []}]},
#     {'citycode': '0755',
#      'adcode': '440310',
#      'name': '坪山区',
#      'center': '114.338441,22.69423',
#      'level': 'district',
#      'districts': [{'citycode': '0755',
#        'adcode': '440310',
#        'name': '坑梓街道',
#        'center': '114.418,22.7667',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440310',
#        'name': '坪山街道',
#        'center': '114.384,22.7252',
#        'level': 'street',
#        'districts': []}]},
#     {'citycode': '0755',
#      'adcode': '440309',
#      'name': '龙华区',
#      'center': '114.044346,22.691963',
#      'level': 'district',
#      'districts': [{'citycode': '0755',
#        'adcode': '440309',
#        'name': '观澜街道',
#        'center': '114.068,22.7488',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440309',
#        'name': '民治街道',
#        'center': '114.012,22.6394',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440309',
#        'name': '大浪街道',
#        'center': '114.003,22.7088',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440309',
#        'name': '龙华街道',
#        'center': '114.01,22.6723',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440309',
#        'name': '福城街道',
#        'center': '113.991,22.7255',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440309',
#        'name': '观湖街道',
#        'center': '114.083,22.6645',
#        'level': 'street',
#        'districts': []}]},
#     {'citycode': '0755',
#      'adcode': '440307',
#      'name': '龙岗区',
#      'center': '114.251372,22.721511',
#      'level': 'district',
#      'districts': [{'citycode': '0755',
#        'adcode': '440307',
#        'name': '横岗街道',
#        'center': '114.166,22.6363',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440307',
#        'name': '深圳市大工业区',
#        'center': '114.34,22.7141',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440307',
#        'name': '南澳街道',
#        'center': '114.503,22.5471',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440307',
#        'name': '龙岗街道',
#        'center': '114.256,22.6783',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440307',
#        'name': '平湖街道',
#        'center': '114.097,22.6914',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440307',
#        'name': '坪地街道',
#        'center': '114.268,22.7879',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440307',
#        'name': '布吉街道',
#        'center': '114.104,22.6673',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440307',
#        'name': '龙城街道',
#        'center': '114.203,22.7553',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440307',
#        'name': '坂田街道',
#        'center': '114.054,22.6659',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440307',
#        'name': '南湾街道',
#        'center': '114.121,22.6347',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440307',
#        'name': '葵涌街道',
#        'center': '114.48,22.6637',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440307',
#        'name': '大鹏街道',
#        'center': '114.546,22.6278',
#        'level': 'street',
#        'districts': []}]},
#     {'citycode': '0755',
#      'adcode': '440311',
#      'name': '光明区',
#      'center': '113.935895,22.748816',
#      'level': 'district',
#      'districts': [{'citycode': '0755',
#        'adcode': '440311',
#        'name': '光明街道',
#        'center': '113.993,22.7558',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440311',
#        'name': '公明街道',
#        'center': '113.914,22.7718',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440311',
#        'name': '马田街道',
#        'center': '113.858,22.7872',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440311',
#        'name': '凤凰街道',
#        'center': '113.921,22.7273',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440311',
#        'name': '玉塘街道',
#        'center': '113.904,22.6976',
#        'level': 'street',
#        'districts': []},
#       {'citycode': '0755',
#        'adcode': '440311',
#        'name': '新湖街道',
#        'center': '113.996,22.7685',
#        'level': 'street',
#        'districts': []}]}]}]}

# %% [markdown]
# ## 搜索POI

# %%
key_map='e74e30eea477decea257a35187b91d58'
def text(keywords):
    """搜索POI"""
    url='https://restapi.amap.com/v3/place/text?parameters'
    params={
        'key':key_map,
        'keywords':'麦当劳|肯德基',
        'type':2,
        'city':'440117',
        'citylimit':'true',
        'extensions':'base',
        'output':'json',
    }
    response=requests.get(url,params=params)
    data=response.json()
    return data
text('麦当劳|肯德基')
# Out:
# {'status': '1',
#  'count': '19',
#  'info': 'OK',
#  'infocode': '10000',
#  'suggestion': {'keywords': [], 'cities': []},
#  'pois': [{'id': 'B00140BNGX',
#    'parent': 'B00140AXVL',
#    'childtype': '202',
#    'name': '麦当劳(从化新世纪广场分店)',
#    'type': '餐饮服务;快餐厅;麦当劳',
#    'typecode': '050302',
#    'biz_type': 'diner',
#    'address': '新城路68号新世纪广场1层',
#    'location': '113.588862,23.547556',
#    'tel': '020-87921092',
#    'distance': [],
#    'biz_ext': [],
#    'pname': '广东省',
#    'cityname': '广州市',
#    'adname': '从化区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'photos': []},
#   {'id': 'B0FFFT24X0',
#    'parent': 'B0FFFPVSH2',
#    'childtype': '202',
#    'name': '麦当劳(从城大道分店)',
#    'type': '餐饮服务;快餐厅;麦当劳',
#    'typecode': '050302',
#    'biz_type': 'diner',
#    'address': '江埔街海塱东路9号',
#    'location': '113.589835,23.531444',
#    'tel': '020-37507910',
#    'distance': [],
#    'biz_ext': [],
#    'pname': '广东省',
#    'cityname': '广州市',
#    'adname': '从化区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'photos': []},
#   {'id': 'B0FFFAIH7Z',
#    'parent': [],
#    'childtype': [],
#    'name': '肯德基(从城大道KFC店)',
#    'type': '餐饮服务;快餐厅;肯德基',
#    'typecode': '050301',
#    'biz_type': 'diner',
#    'address': '从城大道111号',
#    'location': '113.590680,23.532120',
#    'tel': '020-37907759;4009200715',
#    'distance': [],
#    'biz_ext': [],
#    'pname': '广东省',
#    'cityname': '广州市',
#    'adname': '从化区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'photos': []},
#   {'id': 'B0FFFVDQ6A',
#    'parent': 'B0FFF04ASX',
#    'childtype': '202',
#    'name': '肯德基(新光DT店)',
#    'type': '餐饮服务;快餐厅;肯德基',
#    'typecode': '050301',
#    'biz_type': 'diner',
#    'address': '广从南路546号新光·百德广场1层',
#    'location': '113.491633,23.448368',
#    'tel': '020-62161512;020-62161513',
#    'distance': [],
#    'biz_ext': [],
#    'pname': '广东省',
#    'cityname': '广州市',
#    'adname': '从化区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'photos': []},
#   {'id': 'B00140TWK0',
#    'parent': 'B00140UGAP',
#    'childtype': '202',
#    'name': '肯德基(新世纪店)',
#    'type': '餐饮服务;快餐厅;肯德基',
#    'typecode': '050301',
#    'biz_type': 'diner',
#    'address': '新城东路66号林苑大厦1-2层',
#    'location': '113.587830,23.547694',
#    'tel': '020-87939891;020-87939871;18028651407',
#    'distance': [],
#    'biz_ext': [],
#    'pname': '广东省',
#    'cityname': '广州市',
#    'adname': '从化区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'photos': []},
#   {'id': 'B00141KAZT',
#    'parent': [],
#    'childtype': [],
#    'name': '肯德基(从化汽车站店)',
#    'type': '餐饮服务;快餐厅;肯德基',
#    'typecode': '050301',
#    'biz_type': 'diner',
#    'address': '江浦街从城大道28号从化汽车站1-2层',
#    'location': '113.598848,23.528025',
#    'tel': '020-37987021;4006630666',
#    'distance': [],
#    'biz_ext': [],
#    'pname': '广东省',
#    'cityname': '广州市',
#    'adname': '从化区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'photos': []},
#   {'id': 'B0FFI8ZPGU',
#    'parent': 'B00140UGAP',
#    'childtype': '202',
#    'name': '肯德基甜品站(新世纪店)',
#    'type': '餐饮服务;快餐厅;快餐厅',
#    'typecode': '050300',
#    'biz_type': 'diner',
#    'address': '新城东路66号林苑大厦首二层',
#    'location': '113.587960,23.547679',
#    'tel': '020-87939871',
#    'distance': [],
#    'biz_ext': [],
#    'pname': '广东省',
#    'cityname': '广州市',
#    'adname': '从化区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'photos': []},
#   {'id': 'B0FFIEMQA0',
#    'parent': [],
#    'childtype': [],
#    'name': '麦当劳甜品站(广百百货店)',
#    'type': '餐饮服务;冷饮店;冷饮店',
#    'typecode': '050700',
#    'biz_type': 'diner',
#    'address': '教育路与西宁中路交叉口西50米',
#    'location': '113.587180,23.550981',
#    'tel': [],
#    'distance': [],
#    'biz_ext': [],
#    'pname': '广东省',
#    'cityname': '广州市',
#    'adname': '从化区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'photos': []},
#   {'id': 'B00141IKX5',
#    'parent': 'B00141IC82',
#    'childtype': '311',
#    'name': '瓦窑岗服务区麦当劳',
#    'type': '餐饮服务;快餐厅;麦当劳',
#    'typecode': '050302',
#    'biz_type': 'diner',
#    'address': '瓦窑岗服务区东区',
#    'location': '113.463881,23.613052',
#    'tel': '020-87880811;020-37976567',
#    'distance': [],
#    'biz_ext': [],
#    'pname': '广东省',
#    'cityname': '广州市',
#    'adname': '从化区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'photos': []},
#   {'id': 'B0FFK7LAZF',
#    'parent': 'B00140AXVL',
#    'childtype': '202',
#    'name': '麦当劳(新世纪广场分店)-洗手间',
#    'type': '公共设施;公共厕所;公共厕所',
#    'typecode': '200300',
#    'biz_type': [],
#    'address': '街口街东成路68号新世纪广场',
#    'location': '113.588919,23.547782',
#    'tel': [],
#    'distance': [],
#    'biz_ext': [],
#    'pname': '广东省',
#    'cityname': '广州市',
#    'adname': '从化区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '2',
#    'poiweight': [],
#    'photos': []},
#   {'id': 'B0FFFDQPKI',
#    'parent': 'B00140UGAP',
#    'childtype': '202',
#    'name': '肯德基(新世纪餐厅)-洗手间',
#    'type': '公共设施;公共厕所;公共厕所',
#    'typecode': '200300',
#    'biz_type': [],
#    'address': '新城东路66号林苑大厦1-2楼(近府前路)',
#    'location': '113.587751,23.547810',
#    'tel': [],
#    'distance': [],
#    'biz_ext': [],
#    'pname': '广东省',
#    'cityname': '广州市',
#    'adname': '从化区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '2',
#    'poiweight': [],
#    'photos': []},
#   {'id': 'B0FFGY8IHS',
#    'parent': [],
#    'childtype': [],
#    'name': '四云奶盖贡茶(华润万家店)',
#    'type': '餐饮服务;甜品店;甜品店',
#    'typecode': '050900',
#    'biz_type': 'diner',
#    'address': '从城大道海塱横街4号(华润万家麦当劳对面)',
#    'location': '113.589315,23.531397',
#    'tel': '18665624168',
#    'distance': [],
#    'biz_ext': [],
#    'pname': '广东省',
#    'cityname': '广州市',
#    'adname': '从化区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'photos': []},
#   {'id': 'B0FFKXLRTS',
#    'parent': [],
#    'childtype': [],
#    'name': '椒红串串料理(欣荣宏店)',
#    'type': '餐饮服务;外国餐厅;外国餐厅',
#    'typecode': '050200',
#    'biz_type': 'diner',
#    'address': '海塱东路欣荣时尚广场b栋127铺(肯德基背后)',
#    'location': '113.590583,23.532066',
#    'tel': [],
#    'distance': [],
#    'biz_ext': [],
#    'pname': '广东省',
#    'cityname': '广州市',
#    'adname': '从化区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'photos': []},
#   {'id': 'B0FFK1SZNO',
#    'parent': 'B00141P6DH',
#    'childtype': '202',
#    'name': '益禾堂(新世纪店)',
#    'type': '餐饮服务;餐饮相关场所;餐饮相关',
#    'typecode': '050000',
#    'biz_type': 'diner',
#    'address': '街口街东成路68号D0006铺(广百麦当劳1楼,回味果屋旁边)',
#    'location': '113.588712,23.547486',
#    'tel': '18585371766',
#    'distance': [],
#    'biz_ext': [],
#    'pname': '广东省',
#    'cityname': '广州市',
#    'adname': '从化区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'photos': []},
#   {'id': 'B0FFJIOJLX',
#    'parent': 'B00141IC82',
#    'childtype': '311',
#    'name': '瓦窑岗服务区充电站',
#    'type': '汽车服务;充电站;充电站',
#    'typecode': '011100',
#    'biz_type': [],
#    'address': '鳌头镇麦当劳(瓦窑岗东区餐厅)',
#    'location': '113.463753,23.613321',
#    'tel': [],
#    'distance': [],
#    'biz_ext': [],
#    'pname': '广东省',
#    'cityname': '广州市',
#    'adname': '从化区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'photos': []},
#   {'id': 'B0FFG59UUN',
#    'parent': [],
#    'childtype': [],
#    'name': '石磨源甜品店',
#    'type': '餐饮服务;甜品店;甜品店',
#    'typecode': '050900',
#    'biz_type': 'diner',
#    'address': '从化街口街新城东路5巷4栋101号(府前路KFC斜对面红蜻蜓专卖店后面)',
#    'location': '113.587429,23.547329',
#    'tel': '020-37505665;18688855733',
#    'distance': [],
#    'biz_ext': [],
#    'pname': '广东省',
#    'cityname': '广州市',
#    'adname': '从化区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'photos': []},
#   {'id': 'B0FFGM9S4V',
#    'parent': [],
#    'childtype': [],
#    'name': '源代码信息科技有限公司',
#    'type': '公司企业;公司;公司',
#    'typecode': '170200',
#    'biz_type': [],
#    'address': '广从南路546号之十六(新光百德广场肯德基傍边)',
#    'location': '113.491683,23.448561',
#    'tel': '020-37512059',
#    'distance': [],
#    'biz_ext': [],
#    'pname': '广东省',
#    'cityname': '广州市',
#    'adname': '从化区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'photos': []},
#   {'id': 'B0FFFALE9C',
#    'parent': [],
#    'childtype': [],
#    'name': '明朗酒店',
#    'type': '住宿服务;宾馆酒店;三星级宾馆',
#    'typecode': '100104',
#    'biz_type': 'hotel',
#    'address': '新城东路68号(即新世纪广场肯德基旁)',
#    'location': '113.587826,23.547652',
#    'tel': '020-87926888;020-37508088',
#    'distance': [],
#    'biz_ext': [],
#    'pname': '广东省',
#    'cityname': '广州市',
#    'adname': '从化区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'photos': []},
#   {'id': 'B0FFJ62BFY',
#    'parent': [],
#    'childtype': [],
#    'name': '晶亮视光(从化店)',
#    'type': '购物服务;购物相关场所;购物相关场所',
#    'typecode': '060000',
#    'biz_type': [],
#    'address': '新城东路68号主楼第一层(新世纪广场肯德基旁)',
#    'location': '113.587429,23.550076',
#    'tel': '020-87959869',
#    'distance': [],
#    'biz_ext': [],
#    'pname': '广东省',
#    'cityname': '广州市',
#    'adname': '从化区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'photos': []}]}

# %% [markdown]
# ## IP定位

# %%
key_map='e74e30eea477decea257a35187b91d58'
def ip():
    """IP定位"""
    url='https://restapi.amap.com/v3/ip?parameters'
    params={
        'key':key_map,
        'ip':'10.10.240.37',
        'output':'json',
    }
    response=requests.get(url,params=params)
    data=response.json()
    return data
ip()
# Out:
# {'status': '1',
#  'info': 'OK',
#  'infocode': '10000',
#  'province': '局域网',
#  'city': [],
#  'adcode': [],
#  'rectangle': []}

# %% [markdown]
# ## 批量请求接口

# %%
url_api="https://restapi.amap.com/v3/batch?key=<e74e30eea477decea257a35187b91d58>" 
{
    "ops": [
        {
            "url": "/v3/place/around?offset=10&page=1&key=<e74e30eea477decea257a35187b91d58>&location=116.50394379585519,39.278209477408794&output=json&radius=100000&types=080000"
        },
        {
            "url": "/v3/place/around?offset=10&page=1&key=<e74e30eea477decea257a35187b91d58>&location=118.50394379585519,39.278209477408794&output=json&radius=100000&types=080000"
        }
    ]
}
# Out:
# {'ops': [{'url': '/v3/place/around?offset=10&page=1&key=<e74e30eea477decea257a35187b91d58>&location=116.50394379585519,39.278209477408794&output=json&radius=100000&types=080000'},
#   {'url': '/v3/place/around?offset=10&page=1&key=<e74e30eea477decea257a35187b91d58>&location=118.50394379585519,39.278209477408794&output=json&radius=100000&types=080000'}]}

# %% [markdown]
# ## 静态地图

# %%
import requests
from PIL import Image
from io import BytesIO

def ditu(location):
    url_api="http://restapi.amap.com/v3/staticmap" 
    parameters = {'key': 'e74e30eea477decea257a35187b91d58', 
              'location':'113.491633,23.448368',
              'zoom':13,
              'size':'1024*768'
              }
    response=requests.get(url_api, params=parameters)
    data=Image.open(BytesIO(response.content))
    return data
ditu('113.491633,23.448368')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=1024x768 at 0x1AE61DF0080>

# %% [markdown]
# ## 坐标转化

# %%
key_map='e74e30eea477decea257a35187b91d58'
def convert(locations):
    """坐标转化"""
    url='https://restapi.amap.com/v3/assistant/coordinate/convert?parameters'
    params={
        'key':key_map,
        'locations':'38.65777,104.08296',
        'coordsys':'mapbar',
        'output':'json',
    }
    response=requests.get(url,params=params)
    data=response.json()
    return data
convert('38.65777,104.08296') #百度坐标
# Out:
# {'status': '1',
#  'info': 'ok',
#  'infocode': '10000',
#  'locations': '38.65033,104.0771'}

# %% [markdown]
# ## 天气查询

# %%
key_map='e74e30eea477decea257a35187b91d58'
def weather(city):
    """天气查询"""
    url='https://restapi.amap.com/v3/weather/weatherInfo?parameters'
    params={
        'key':key_map,
        'city':440117 ,
        'extensions':'base',
        'output':'json',
    }
    response=requests.get(url,params=params)
    data=response.json()
    return data

# %%
weather('440117')
# Out:
# {'status': '1',
#  'count': '1',
#  'info': 'OK',
#  'infocode': '10000',
#  'lives': [{'province': '广东',
#    'city': '从化区',
#    'adcode': '440117',
#    'weather': '晴',
#    'temperature': '21',
#    'winddirection': '东北',
#    'windpower': '≤3',
#    'humidity': '75',
#    'reporttime': '2019-10-19 16:45:02'}]}

# %% [markdown]
# ## 输入提示

# %%
key_map='e74e30eea477decea257a35187b91d58'
def inputtips(keywords):
    """输入提示"""
    url='https://restapi.amap.com/v3/assistant/inputtips?parameters'
    params={
        'key':key_map,
        'keywords':'肯德基',
        'city':440117,
        'output':'json',
    }
    response=requests.get(url,params=params)
    data=response.json()
    return data

# %%
inputtips('肯德基')
# Out:
# {'status': '1',
#  'count': '10',
#  'info': 'OK',
#  'infocode': '10000',
#  'tips': [{'id': [],
#    'name': '肯德基',
#    'district': [],
#    'adcode': [],
#    'location': [],
#    'address': [],
#    'typecode': [],
#    'city': []},
#   {'id': 'B00140UEQ5',
#    'name': '肯德基(中山四店)',
#    'district': '广东省广州市越秀区',
#    'adcode': '440104',
#    'location': '113.273300,23.125993',
#    'address': '中山四路199号东鸣轩1层',
#    'typecode': '050301',
#    'city': []},
#   {'id': 'B00140C0X9',
#    'name': '肯德基(五月花店)',
#    'district': '广东省广州市越秀区',
#    'adcode': '440104',
#    'location': '113.267089,23.125895',
#    'address': '中山五路68号五月花商业广场B2层B221-B225',
#    'typecode': '050301',
#    'city': []},
#   {'id': 'B00140T531',
#    'name': '肯德基(光明广场店)',
#    'district': '广东省广州市越秀区',
#    'adcode': '440104',
#    'location': '113.267228,23.122873',
#    'address': '西湖路63号光明广场2F层',
#    'typecode': '050301',
#    'city': []},
#   {'id': 'B00140U1MF',
#    'name': '肯德基(署前店)',
#    'district': '广东省广州市越秀区',
#    'adcode': '440104',
#    'location': '113.295125,23.123366',
#    'address': '署前路33号1-2层',
#    'typecode': '050301',
#    'city': []},
#   {'id': 'B00140AEMR',
#    'name': '肯德基(锦轩店)',
#    'district': '广东省广州市越秀区',
#    'adcode': '440104',
#    'location': '113.295986,23.125776',
#    'address': '农林下路4-6号锦轩现代城1层',
#    'typecode': '050301',
#    'city': []},
#   {'id': 'B00141IEYA',
#    'name': '肯德基(淘金店)',
#    'district': '广东省广州市越秀区',
#    'adcode': '440104',
#    'location': '113.287706,23.139518',
#    'address': '淘金路淘金街6-8号1楼(世贸大厦后面)',
#    'typecode': '050301',
#    'city': []},
#   {'id': 'B00140UOHC',
#    'name': '肯德基(中六乐购店)',
#    'district': '广东省广州市越秀区',
#    'adcode': '440104',
#    'location': '113.255050,23.124989',
#    'address': '中山六路281号上品轩B1层',
#    'typecode': '050301',
#    'city': []},
#   {'id': 'B0FFF0EPRU',
#    'name': '肯德基(滨江东店KFC店)',
#    'district': '广东省广州市海珠区',
#    'adcode': '440105',
#    'location': '113.293046,23.103682',
#    'address': '滨江东路35滨江壹号购物商场附近',
#    'typecode': '050301',
#    'city': []},
#   {'id': 'B00140UI3A',
#    'name': '肯德基(东峻广场店)',
#    'district': '广东省广州市越秀区',
#    'adcode': '440104',
#    'location': '113.306625,23.131587',
#    'address': '东风东路836号东峻广场西园首层29、30号',
#    'typecode': '050301',
#    'city': []}]}

# %% [markdown]
# ## 交通态势

# %%
key_map='e74e30eea477decea257a35187b91d58'
def circle():
    """指定线路交通态势"""
    url='https://restapi.amap.com/v3/traffic/status/circle?parameters'
    params={
        'key':key_map,
        'level':4,
        'adcode':440105,
        'name':'滨江东路',
        'extensions':'base',
        'location':'113.293046,23.103682,',
        'output':'json',
    }
    response=requests.get(url,params=params)
    data=response.json()
    return data
circle()
# Out:
# {'status': '1',
#  'info': 'OK',
#  'infocode': '10000',
#  'trafficinfo': {'description': '东晓路：自北向南缓慢，从仲恺路到内环路出口严重拥堵；１１８省道：从汇太西路到东坑三横路行驶缓慢；仲恺路：自西向东缓慢，反向畅通；潭月街：自北向南缓慢。',
#   'evaluation': {'expedite': '65.00%',
#    'congested': '20.00%',
#    'blocked': '5.00%',
#    'unknown': '10.00%',
#    'status': '2',
#    'description': '轻度拥堵'}}}

# %% [markdown]
# ## 地理围栏

# %%
def meta():
    """创建围栏"""
    url='https://restapi.amap.com/v4/geofence/meta?key=e74e30eea477decea257a35187b91d58'
    params={
        'name':"围栏名称",
        'center':'113.293046,23.103682',
        'radius':'3000', 
        'enable': 'true',
        'repeat': 'Mon,Tues,Wed,Thur,Fri,Sat,Sun',
        'valid_time': '2019-10-19'
    }
    data=requests.post(url,json=params).json()
    return data
meta()
# Out:
# {'data': {'gid': '04da5329-19f4-4fa2-a63d-163a76b92ef1',
#   'id': '0',
#   'message': '成功',
#   'status': '0'},
#  'errcode': 0,
#  'errdetail': None,
#  'errmsg': 'OK',
#  'ext': None}

# %% [markdown]
# ## 轨迹纠偏

# %%
key_map='e74e30eea477decea257a35187b91d58'
def add(name):
    """创建服务"""
    url='https://tsapi.amap.com/v1/track/service/add'
    params={
        'key':key_map,
        'name':'广州佛山',
    }
    response=requests.post(url,params=params)
    data=response.json()
    return data
add('name')
# Out:
# {'data': {'name': '广州佛山', 'sid': 78057},
#  'errcode': 10000,
#  'errdetail': None,
#  'errmsg': 'OK'}

# %%
key_map='e74e30eea477decea257a35187b91d58'
def list():
    """查询服务"""
    url='https://tsapi.amap.com/v1/track/service/list'
    params={
        'key':key_map,
    }
    response=requests.get(url,params=params)
    data=response.json()
    return data
list()
# Out:
# {'data': {'results': [{'desc': None, 'name': '广州从化', 'sid': 77317},
#    {'desc': None, 'name': '广州龙岗', 'sid': 78178},
#    {'desc': None, 'name': '广州佛山', 'sid': 78057}]},
#  'errcode': 10000,
#  'errdetail': None,
#  'errmsg': 'OK'}

# %% [markdown]
# # 在调用每一个功能的同时，思考其背后是否含有ML、AI的功能（比如计算机视觉、语音识别、推荐算法等），并整理思考的结果，在调用API代码模块中用markdown说明
#
# ## 地理编码-获取地理编码
# *地理编码：将详细的结构化地址转换为高德经纬度坐标。且支持对地标性名胜景区、建筑物名称解析为高德经纬度坐标。*
# ## 路径规划-步行路径规划
# *路径规划API是一套以HTTP形式提供的步行、公交、驾车查询及行驶距离计算接口，返回JSON 或 XML格式的查询数据，用于实现路径规划功能的开发*
# ## 行政区域查询
# *根据用户输入的搜索条件可以帮助用户快速的查找特定的行政区域信息。*
# ## 搜索POI
# *提供多种查询POI信息的能力，其中包括关键字搜索、周边搜索、多边形搜索、ID查询四种筛选机制。*
# ## IP定位
# *根据用户输入的IP地址，能够快速的帮用户定位IP的所在位置。*
# ## 静态地图
# *静态地图服务通过返回一张地图图片响应HTTP请求，使用户能够将高德地图以图片形式嵌入自己的网页中。用户可以指定请求的地图位置、图片大小、以及在地图上添加覆盖物，如标签、标注、折线、多边形。*
# ## 坐标转换
# *坐标转换是一类简单的HTTP接口，能够将用户输入的非高德坐标（GPS坐标、mapbar坐标、baidu坐标）转换成高德坐标。*
# ## 天气查询
# *根据用户输入的adcode，查询目标区域当前/未来的天气情况。*
# ## 输入提示
# *提供根据用户输入的关键词查询返回建议列表。*
# ## 交通态势-指定线路交通态势
# *提供根据用户输入的内容能够返回希望查询的交通态势情况。*
# ## 地理围栏-创建围栏
# *提供在服务端，增删改查地理围栏的功能，同时支持对于设备与围栏关系进行监控*
# ## 轨迹纠偏-创建服务、查询服务
# *根据坐标点抓取道路，即根据给定的坐标点、车辆的方位角以及行驶速度，将用户的轨迹纠偏到路上，从而返回用户实际驾车经过的道路坐标。*
#
# ### 整理发现
#
# 高德API中的**路径规划**类似于人工智能AI的路径规划，计算当前道路的拥挤状况，推荐最佳的路径选择。
#
# **静态地图**则是运用了计算机视觉，将周围的环境通过视觉语言的形式呈现出来，还有路标，位置信息，道路等。
#
# **IP定位**、**天气查询**、**交通态势**、**输入提示**、**地理围栏**和**轨迹纠偏**，我觉得背后的是用人工智能的算法推荐，才能获得信息。

# %% [markdown]
# # 尝试设计一个简单的应用（不要求写代码），至少涉及3个API功能。
#
# ### API调用
# - 天气查询
# - 交通态势
# - 路径规划
# - 输入提示
#
# ### 主要功能
#
# 出门前查询当前的天气，搜索到达的目的地，搜索目的地的同时有输入提示用户，展示当前的交通路况，并为用户提供最佳的路径。
